# %% [markdown]
# I follow the image classification tutorial from tensor flow which can be found here:
#
# https://www.tensorflow.org/tutorials/images/classification
#
# I use my own dataset of flags which was scraped from the internet.
#
# This is just a learning notebook and so I won't be detailing each step.

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

import pandas as pd

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    'C:/Users/Dave/Documents/Jupyter Notebooks/Flags/images',
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(100, 100),
    shuffle=True,
    seed=123,
    validation_split=0.2,
    subset='training',
    interpolation="bilinear",
    follow_links=False,
)
# Out:
# Found 61953 files belonging to 227 classes.
# Using 49563 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    'C:/Users/Dave/Documents/Jupyter Notebooks/Flags/images',
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(100, 100),
    shuffle=True,
    seed=123,
    validation_split=0.2,
    subset='validation',
    interpolation="bilinear",
    follow_links=False,
)
# Out:
# Found 61953 files belonging to 227 classes.
# Using 12390 files for validation.

# %%
class_names = train_ds.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

# cache () keeps the images in memory after they're loaded off disk during the first epoch
# prefetch() overlaps data preprocessing and model execution while training. 
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %%
num_classes = 227

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(100, 100, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# rescaling_1 (Rescaling)      (None, 100, 100, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 100, 100, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 50, 50, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 50, 50, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 25, 25, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 64)        0
# ...

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 1700/1700 [==============================] - 710s 390ms/step - loss: 3.9220 - accuracy: 0.2548 - val_loss: 2.6267 - val_accuracy: 0.4906
# Epoch 2/10
# 1700/1700 [==============================] - 360s 211ms/step - loss: 2.3301 - accuracy: 0.5311 - val_loss: 2.4388 - val_accuracy: 0.5238
# Epoch 3/10
# 1700/1700 [==============================] - 352s 207ms/step - loss: 1.9019 - accuracy: 0.6005 - val_loss: 2.3604 - val_accuracy: 0.5516
# Epoch 4/10
# 1700/1700 [==============================] - 326s 191ms/step - loss: 1.5436 - accuracy: 0.6631 - val_loss: 2.4444 - val_accuracy: 0.5500
# Epoch 5/10
# 1700/1700 [==============================] - 317s 187ms/step - loss: 1.2217 - accuracy: 0.7188 - val_loss: 2.6592 - val_accuracy: 0.5579
# Epoch 6/10
# 1700/1700 [==============================] - 338s 199ms/step - loss: 0.9543 - accuracy: 0.7715 - val_loss: 3.0653 - val_accuracy: 0.5503
# Epoch 7/10
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Removed bad samples

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=(100, 100, 3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# sequential_1 (Sequential)    (None, 100, 100, 3)       0
# _________________________________________________________________
# rescaling_2 (Rescaling)      (None, 100, 100, 3)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 100, 100, 16)      448
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 50, 50, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 50, 50, 32)        4640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 25, 25, 64)        18496
# ...

# %%
epochs = 15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# 1549/1549 [==============================] - 427s 248ms/step - loss: 4.0474 - accuracy: 0.2044 - val_loss: 2.5294 - val_accuracy: 0.4864
# Epoch 2/15
# 1549/1549 [==============================] - 357s 230ms/step - loss: 2.4395 - accuracy: 0.4907 - val_loss: 2.2886 - val_accuracy: 0.5298
# Epoch 3/15
# 1549/1549 [==============================] - 353s 228ms/step - loss: 2.1710 - accuracy: 0.5404 - val_loss: 2.1319 - val_accuracy: 0.5672
# Epoch 4/15
# 1549/1549 [==============================] - 356s 230ms/step - loss: 2.0255 - accuracy: 0.5683 - val_loss: 2.0565 - val_accuracy: 0.5830
# Epoch 5/15
# 1549/1549 [==============================] - 357s 231ms/step - loss: 1.9285 - accuracy: 0.5863 - val_loss: 2.0514 - val_accuracy: 0.5835
# Epoch 6/15
# 1549/1549 [==============================] - 353s 228ms/step - loss: 1.8417 - accuracy: 0.5994 - val_loss: 2.0214 - val_accuracy: 0.5913
# Epoch 7/15
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### Predict the flag of a picture not in the training set

# %%
flag_url = 'C:/Users/Dave/Documents/Jupyter Notebooks/Flags/PanamaTest.JPG'
#flag_path = tf.keras.utils.get_file('PanamaTest', origin=flag_url)

img = keras.preprocessing.image.load_img(
    flag_url, target_size=(100, 100)
)

plt.figure()

plt.imshow(img)

plt.axis("off")
# Out:
# (-0.5, 99.5, 99.5, -0.5)

# %%
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to France with a 19.27 percent confidence.

# %%
top_k_values, top_k_indices = tf.nn.top_k(score, k=10)

# %%
for value, flag in zip(np.array(top_k_values), top_k_indices):
    print('Flag is ' + str(class_names[flag]) + ' with confidence ' + str(value))
# Out:
# Flag is France with confidence 0.1926887
# Flag is Yemen with confidence 0.08794516
# Flag is Netherlands with confidence 0.085463375
# Flag is Dominican Republic with confidence 0.06555087
# Flag is Guatemala with confidence 0.05508001
# Flag is Egypt with confidence 0.051747087
# Flag is Israel with confidence 0.045749273
# Flag is Cuba with confidence 0.042577423
# Flag is Paraguay with confidence 0.024885003
# Flag is Taiwan with confidence 0.023737103

# %%
top_k_indices
# Out:
# <tf.Tensor: shape=(10,), dtype=int32, numpy=array([ 69, 224, 147,  57,  84,  60, 100,  51, 160, 198])>

# %%
print(score[158])
# Out:
# tf.Tensor(0.017492885, shape=(), dtype=float32)
